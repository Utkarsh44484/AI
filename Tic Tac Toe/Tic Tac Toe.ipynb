# %%
from IPython.display import clear_output
def printing(c,k,a):
    if k%2==1:
        a[c]='X'
    else:
        a[c]='O'
        
    clear_output()
    print("Your Current Game ")
    print("    |    |    ")
    print(" {}  | {}  | {} ".format(a[7],a[8],a[9]))
    print("----+----+----")
    print(" {}  | {}  | {} ".format(a[4],a[5],a[6]))
    print("----+----+----")
    print(" {}  | {}  | {} ".format(a[1],a[2],a[3]))
    print("    |    |    ")
    if (a[1]==a[2]==a[3]!=' ') or (a[4]==a[5]==a[6]!=' ') or (a[7]==a[8]==a[9]!=' ')  or (a[1]==a[4]==a[7]!=' ') or (a[5]==a[2]==a[8]!=' ') or (a[6]==a[9]==a[3]!=' ') or (a[1]==a[5]==a[9]!=' ') or (a[5]==a[7]==a[3]!=' '):
        x1=a.count('X')
        x2=a.count('O')
        if(x1>x2):
            print("Player 1 won ")
            return 2
        else:
            print("Player 2 won ")
            return 2
            
        
        
        
    if ' ' not in a:
        return -1
    else :
        return 0

# %%
def start():
    print("Welcome to Tic Tac Toe ")
    print("To know how to play press 1 and to ignore this press any other number ")
    t=int(input())
    if(t==1):
        how_to_play()
    a=[' ']*10
    a[0]=1
    print("Your Current Game ")
    print("    |    |    ")
    print(" {}  | {}  | {} ".format(a[7],a[8],a[9]))
    print("----+----+----")
    print(" {}  | {}  | {} ".format(a[4],a[5],a[6]))
    print("----+----+----")
    print(" {}  | {}  | {} ".format(a[1],a[2],a[3]))
    print("    |    |    ")
    print("\n")
    print("\n")

    
    print("Player 1 will start now ")
    
    play(a)
    print("\n")
    print("To play Again Press 1 and to stop playing press any other number")
    choice=int(input())
    return choice

# %%
from IPython.display import clear_output
def how_to_play():
    clear_output()
    print('\n')
    print('\n')
    print("This is a 2 player game")
    print('\n')
    print("player 1 will play first followed by player 2")
    print('\n')
    print("Player 1 will be 'X' and player 2 will be 'O' ")
    print('\n')
    print("Player will win if he/she managed to mark the symbol in a row ")
    print('\n')
    print("Press the following number on keypad to mark at their position ")
    print('\n')
    print("    |    |    ")
    print("  7 | 8  | 9  ")
    print("----+----+----")
    print("  4 | 5  | 6  ")
    print("----+----+----")
    print("  1 | 2  | 3  ")
    print("    |    |    ")
    
    print('\n')
    print('Its is similar to  keypad of your PC')
    print('\n')
    print('\n')

# %%
def play(a):
    print('\n')
    q=0
    k=1
    while(q==0):
    
        if k%2==1:
            print("Player 1 make your move")
        else:
            print("Player 2 make your move")
        choice=int(input())
        q=printing(choice,k,a)
        if q==-1:
            print('\n')
            print("Game Drawn")
            print("Well played")
            print('\n')
        if q==2:
            
            
            print("Well played")
            print('\n')
            
            
        k+=1

# %%
def game():
    y=1
    while(y==1):
        y=start()
        if y!=1:
            print('\n')
            print('“Time is a game played beautifully by children.”      ----― Heraclitus, Fragments')
            print('\n')
            print("See you again")

# %%
game()
# Out:
# Your Current Game
#     |    |
#  O  | X  | O
# ----+----+----
#  O  | X  |
# ----+----+----
#  X  | O  | X
#     |    |
# Player 1 make your move
